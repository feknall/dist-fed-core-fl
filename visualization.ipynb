# %%
from matplotlib import pyplot as plt

# %%
# FedAvg, 4 Clients

accuracy_list_fedavg_4_msg_10 = [0, 0.5921000242233276, 0.9538999795913696, 0.9671000242233276, 0.9724000096321106, 0.9758999943733215, 0.9771999716758728, 0.979200005531311, 0.9794999957084656, 0.9786999821662903, 0.9799000024795532]
time_list_fedavg_4_msg_10 = [1676072544.141197, 1676072552.3450403, 1676072559.5251076, 1676072566.7006028, 1676072574.160158, 1676072581.5283606, 1676072588.614626, 1676072596.149891, 1676072603.8032274, 1676072610.8992944, 1676072618.7555597]

# %%
# FedAvg, 8 Clients

accuracy_list_fedavg_8 = [0, 0.44279998540878296, 0.9258999824523926, 0.9459999799728394, 0.9584000110626221, 0.9639000296592712, 0.9667999744415283, 0.9717000126838684, 0.9714000225067139, 0.9758999943733215, 0.9754999876022339]
time_list_fedavg_8 = [1675916545.7165082, 1675916556.8604226, 1675916566.5694988, 1675916575.887271, 1675916586.2600877, 1675916594.7975054, 1675916603.7095761, 1675916612.872172, 1675916622.2277777, 1675916631.9216392, 1675916641.0722384]

x = range(len(accuracy_list_fedavg_8))
plt.plot(x, accuracy_list_fedavg_4_msg_10)
plt.plot(x, accuracy_list_fedavg_8)

plt.show()

# %%
# FedAvg, 16 Clients
accuracy_list_fedavg_16 = [0, 0.21449999511241913, 0.8962000012397766, 0.9161999821662903, 0.9315000176429749, 0.9413999915122986, 0.9449999928474426, 0.95169997215271, 0.9556999802589417, 0.958299994468689, 0.9620000123977661]
time_list_fedavg_16 = [1675918994.2979343, 1675919020.7115667, 1675919035.8983848, 1675919051.676706, 1675919067.605748, 1675919082.7539866, 1675919098.2861087, 1675919115.1491191, 1675919131.0638707, 1675919147.546681, 1675919164.8174932]

# %%
x = range(len(accuracy_list_fedavg_8))
plt.plot(x, accuracy_list_fedavg_4_msg_10)
plt.plot(x, accuracy_list_fedavg_8)
plt.plot(x, accuracy_list_fedavg_16)

plt.show()

# %%
# FedAvg, 16 Clients, MaxMessageCount = 20

accuracy_list_fedavg_16_msg_20 = [0, 0.10090000182390213, 0.8980000019073486, 0.9182000160217285, 0.9309999942779541, 0.9401000142097473, 0.946399986743927, 0.9509000182151794, 0.9557999968528748, 0.9591000080108643, 0.9625999927520752]

time_list_fedavg_16_msg_20 = [1676068182.4508896, 1676068208.7746775, 1676068224.8090208, 1676068239.3164454, 1676068255.9274964, 1676068269.901385, 1676068284.1025934, 1676068299.0690775, 1676068313.3124723, 1676068327.5510786, 1676068341.8337073]

# %%
accuracy_list_fedavg_8_msg_20 = [0, 0.4690000116825104, 0.926800012588501, 0.9465000033378601, 0.9555000066757202, 0.9631999731063843, 0.9656999707221985, 0.9713000059127808, 0.9710000157356262, 0.9749000072479248, 0.9750999808311462]

time_list_fedavg_8_msg_20 = [1676070820.1250257, 1676070831.6650488, 1676070840.26078, 1676070848.8287745, 1676070859.3199534, 1676070867.7823002, 1676070876.1341233, 1676070884.6081247, 1676070892.9529207, 1676070901.3337212, 1676070911.0140197]

# %%
accuracy_list_fedavg_4_msg_20 = [0, 0.26100000739097595, 0.9546999931335449, 0.9664000272750854, 0.9732999801635742, 0.9757000207901001, 0.975600004196167, 0.977400004863739, 0.9793999791145325, 0.9796000123023987, 0.980400025844574]

time_list_fedavg_4_msg_20 = [1676071338.735255, 1676071346.7500226, 1676071353.9670305, 1676071361.2034216, 1676071368.626323, 1676071375.904128, 1676071383.5218956, 1676071390.7449403, 1676071398.3538733, 1676071406.5546017, 1676071414.0479398]

# %%
accuracy_list_fedavg_4_msg_5 = [0, 0.6482999920845032, 0.9514999985694885, 0.9671000242233276, 0.972000002861023, 0.9742000102996826, 0.9769999980926514, 0.9768000245094299, 0.9779000282287598, 0.9796000123023987, 0.9801999926567078]

time_list_fedavg_4_msg_5 =  [1676072148.4546266, 1676072156.1107183, 1676072163.2761147, 1676072170.7460666, 1676072178.4015687, 1676072185.4384186, 1676072192.7438118, 1676072199.9539428, 1676072207.3479545, 1676072214.638724, 1676072221.8056386]

# %%
x = range(len(time_list_fedavg_4_msg_5))

plt.plot(x, [x - time_list_fedavg_4_msg_5[0] for x in time_list_fedavg_4_msg_5], label="4-5")
plt.plot(x, [x - time_list_fedavg_4_msg_10[0] for x in time_list_fedavg_4_msg_10], label="4-10")
plt.plot(x, [x - time_list_fedavg_4_msg_20[0] for x in time_list_fedavg_4_msg_20], label="4-20")

# plt.plot(x, [x - time_list_fedavg_8[0] for x in time_list_fedavg_8], label="8-10")
# plt.plot(x, [x - time_list_fedavg_8_msg_20[0] for x in time_list_fedavg_8_msg_20], label="8-20")
#
# plt.plot(x, [x - time_list_fedavg_16[0] for x in time_list_fedavg_16], label="16-10")
# plt.plot(x, [x - time_list_fedavg_16_msg_20[0] for x in time_list_fedavg_16_msg_20], label="16-20")


plt.legend()
plt.show()
