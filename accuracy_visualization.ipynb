# %%
import matplotlib.pyplot as plt

from matplotlib.pyplot import figure

figure(figsize=(8, 3), dpi=200)

round = range(1, 11)

c4_accuracy_list = [0.5627999901771545, 0.9544000029563904, 0.9667999744415283, 0.9722999930381775, 0.9728999733924866, 0.9765999913215637, 0.9776999950408936, 0.9790999889373779, 0.9794999957084656, 0.9807000160217285]

c8_accuracy_list = [0.384799987077713, 0.9247999787330627, 0.9453999996185303, 0.9581999778747559, 0.9635999798774719, 0.967199981212616, 0.9710999727249146, 0.9722999930381775, 0.9725000262260437, 0.9753999710083008]

c16_accuracy_list = [0.120899997651577, 0.8974000215530396, 0.9194999933242798, 0.9329000115394592, 0.9404000043869019, 0.9473000168800354, 0.9520999789237976, 0.9563999772071838, 0.9606999754905701, 0.9620000123977661]

plt.plot(round, c4_accuracy_list, 'b--o', label='m=4')
plt.plot(round, c8_accuracy_list, 'g--*', label='m=8')
plt.plot(round, c16_accuracy_list, 'r--+', label='m=16')

plt.legend()
plt.xticks(round)
plt.xlabel('Round')
plt.ylabel('Accuracy (MNIST)')
plt.show()

# %%
import matplotlib.pyplot as plt

from matplotlib.pyplot import figure

figure(figsize=(8, 3), dpi=200)

number_of_clients = [2, 3, 4, 5, 10, 20, 40]

fedshare_mnist_accuracy = [0.98, 0.98, 0.98, 0.98, 0.97, 0.95, 0.92]
fedavg_mnist_accuracy = [0.98, 0.98, 0.98, 0.98, 0.97, 0.95, 0.92]
scotch_mnist_accuracy = [0.975, 0.965, 0.74, 0.53, 0.13, 0.1, 0.1]

plt.plot(number_of_clients, fedavg_mnist_accuracy, 'b--o', label='FedAvg')
plt.plot(number_of_clients, fedshare_mnist_accuracy, 'g--*', label='FedShare')
plt.plot(number_of_clients, scotch_mnist_accuracy, 'r--+', label='SCOTCH')

plt.legend()
plt.xticks(number_of_clients)
plt.xlabel('Number of Clients')
plt.ylabel('Accuracy (MNIST)')
plt.show()

# %%
fedshare_fmnist_accuracy = [0.87, 0.87, 0.86, 0.85, 0.83, 0.8, 0.75]
fedavg_fmnist_accuracy = [0.88, 0.87, 0.86, 0.85, 0.83, 0.8, 0.75]
scotch_fmnist_accuracy = [0.85, 0.69, 0.53, 0.5, 0.11, 0.1, 0.1]

figure(figsize=(8, 3), dpi=200)

plt.plot(number_of_clients, fedavg_fmnist_accuracy, 'b--o', label='FedAvg')
plt.plot(number_of_clients, fedshare_fmnist_accuracy, 'g--*', label='FedShare')
plt.plot(number_of_clients, scotch_fmnist_accuracy, 'r--+', label='SCOTCH')

plt.legend()
plt.xticks(number_of_clients)
plt.xlabel('Number of Clients')
plt.ylabel('Accuracy (FMNIST)')
plt.show()

# %%
fedshare_emnist_accuracy = [0.99, 0.99, 0.99, 0.99, 0.99, 0.98, 0.97]
fedavg_emnist_accuracy = [0.99, 0.99, 0.99, 0.99, 0.99, 0.98, 0.97]
scotch_emnist_accuracy = [0.985, 0.984, 0.9, 0.549, 0.1, 0.1, 0.1]

figure(figsize=(8, 3), dpi=200)

plt.plot(number_of_clients, fedavg_emnist_accuracy, 'b--o', label='FedAvg')
plt.plot(number_of_clients, fedshare_emnist_accuracy, 'g--*', label='FedShare')
plt.plot(number_of_clients, scotch_emnist_accuracy, 'r--+', label='SCOTCH')

plt.legend()
plt.xticks(number_of_clients)
plt.xlabel('Number of Clients')
plt.ylabel('Accuracy (EMNIST)')
plt.show()

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(5, 9), dpi=200)

fig.tight_layout(pad=3.0)



ax[0].plot(number_of_clients, fedavg_mnist_accuracy, 'b--o', label='FedAvg')
ax[0].plot(number_of_clients, fedshare_mnist_accuracy, 'g--*', label='FedShare')
ax[0].plot(number_of_clients, scotch_mnist_accuracy, 'r--+', label='SCOTCH')
ax[0].set_ylabel('Accuracy')
ax[0].set_title('MNIST')
ax[0].set_xlabel('Number of Clients')
ax[0].legend()

ax[1].plot(number_of_clients, fedavg_fmnist_accuracy, 'b--o', label='FedAvg')
ax[1].plot(number_of_clients, fedshare_fmnist_accuracy, 'g--*', label='FedShare')
ax[1].plot(number_of_clients, scotch_fmnist_accuracy, 'r--+', label='SCOTCH')
ax[1].set_ylabel('Accuracy')
ax[1].set_title('FMNIST')
ax[1].set_xlabel('Number of Clients')
ax[1].legend()

ax[2].plot(number_of_clients, fedavg_emnist_accuracy, 'b--o', label='FedAvg')
ax[2].plot(number_of_clients, fedshare_emnist_accuracy, 'g--*', label='FedShare')
ax[2].plot(number_of_clients, scotch_emnist_accuracy, 'r--+', label='SCOTCH')
ax[2].set_title('EMNIST')
ax[2].set_ylabel('Accuracy')
ax[2].set_xlabel('Number of Clients')

# plt.subplots_adjust(bottom=0.5, top=0.5)

ax[2].legend()
# fig[1].xticks(number_of_clients, rotation=90)


plt.show()

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(5, 6), dpi=200)

fig.tight_layout(pad=-1.0)



ax[0].plot(number_of_clients, fedavg_mnist_accuracy, 'b--o', label='FedAvg')
ax[0].plot(number_of_clients, fedshare_mnist_accuracy, 'g--*', label='FedShare')
ax[0].plot(number_of_clients, scotch_mnist_accuracy, 'r--+', label='SCOTCH')
ax[0].set_ylabel('MNIST\nAccuracy')
# ax[0].set_title('MNIST')
# ax[0].set_xlabel('Number of Clients')
ax[0].legend(loc='upper center', bbox_to_anchor=(0.5, 1.20), ncol=3)

ax[1].plot(number_of_clients, fedavg_fmnist_accuracy, 'b--o', label='FedAvg')
ax[1].plot(number_of_clients, fedshare_fmnist_accuracy, 'g--*', label='FedShare')
ax[1].plot(number_of_clients, scotch_fmnist_accuracy, 'r--+', label='SCOTCH')
ax[1].set_ylabel('FMNIST\nAccuracy')
# ax[1].set_title('')
# ax[1].set_xlabel('Number of Clients')
# ax[1].legend()

ax[2].plot(number_of_clients, fedavg_emnist_accuracy, 'b--o', label='FedAvg')
ax[2].plot(number_of_clients, fedshare_emnist_accuracy, 'g--*', label='FedShare')
ax[2].plot(number_of_clients, scotch_emnist_accuracy, 'r--+', label='SCOTCH')
# ax[2].set_title('')
ax[2].set_ylabel('EMNIST\nAccuracy')
ax[2].set_xlabel('Number of Clients')

# plt.subplots_adjust(bottom=0.5, top=0.5)

# ax[2].legend()

ax[0].set_xticks([])
ax[1].set_xticks([])


plt.show()
